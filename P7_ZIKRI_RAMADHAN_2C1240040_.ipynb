# %% [markdown]
# <a href="https://colab.research.google.com/github/zikriramadhan1/ZIKRI-RAMADHAN/blob/main/P7_ZIKRI_RAMADHAN_2C1240040_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **WHILE LOOP**

# %%
#Contoh penggunaan While Loop
#Catatan: Penentuan ruang lingkup di Python bisa menggunakan tab alih-alih menggunakan tanda kurung

count = 0
while (count < 9):
  print ("The count is: ", count)
  count = count + 1

print ("Good bye!")
# Out:
# The count is:  0
# The count is:  1
# The count is:  2
# The count is:  3
# The count is:  4
# The count is:  5
# The count is:  6
# The count is:  7
# The count is:  8
# Good bye!

# %%
a = 3
# blok while akan dieksekusi
# selama a > 3
while a > 0:
    print("a =", a, "> 0")
    a = a - 1
    print("    a sekarang :", a)

# %%
# contoh INFINITE LOOP
# !!!hentikan program secara manual!!!
# nilai b = 1 dan 1 > 0
# karena nilai b tidak pernah berubah di dalam loop
# maka kondisi akan selalu bernilai True
b = 1     # b akan selalu bernilai 1
while b > 0:
    print("infinite loop")
# Out:
# Streaming output truncated to the last 5000 lines.
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# ...
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop
# infinite loop

# %%
jawab = 'ya'
hitung = 0

while(jawab == 'ya'):
    hitung += 1
    jawab = input("Ulang lagi tidak? ")

print("Total perulagan: ",hitung)

# %% [markdown]
# **FOR LOOP**

# %%
#Contoh pengulangan for sederhana
angka = [1,2,3,4,5]
for x in angka:
  print(x)

# %%
#Contoh pengulangan for
buah = ["nanas", "apel", "jeruk"]
for makanan in buah:
  print ("Saya suka makan", makanan)
# Out:
# Saya suka makan nanas
# Saya suka makan apel
# Saya suka makan jeruk

# %%
ulang = 10

for i in range(ulang):
    print(f"Perulangan ke-{i}")
# Out:
# Perulangan ke-0
# Perulangan ke-1
# Perulangan ke-2
# Perulangan ke-3
# Perulangan ke-4
# Perulangan ke-5
# Perulangan ke-6
# Perulangan ke-7
# Perulangan ke-8
# Perulangan ke-9

# %%
# mencetak "Pikachu" sebanyak 5x
for _ in range(5):
    print("Pikachu")
# Out:
# Pikachu
# Pikachu
# Pikachu
# Pikachu
# Pikachu

# %%
# mencetak nilai kuadrat 1-10 dengan step=2
for val in range(1, 10, 2):
    val_kuadrat = val**2
    print(f"{val}^2 adalah {val_kuadrat}")
# Out:
# 1^2 adalah 1
# 3^2 adalah 9
# 5^2 adalah 25
# 7^2 adalah 49
# 9^2 adalah 81

# %%
# iterasi pada list
skills = ["Python", "R", "Julia", "Scala"]
for skill in skills:
    print("Anda menguasai", skill)
print("-------------------------")
# iterasi pada list dengan menyertakan indeks (key)
for idx, skill in enumerate(skills):
    print(f"Skill ke-{idx+1} : {skill}")
# Out:
# Anda menguasai Python
# Anda menguasai R
# Anda menguasai Julia
# Anda menguasai Scala
# -------------------------
# Skill ke-1 : Python
# Skill ke-2 : R
# Skill ke-3 : Julia
# Skill ke-4 : Scala

# %% [markdown]
# **NESTED LOOP**

# %%
# Program Python dengan Nested Loop

# Input jumlah baris
baris = int(input("Masukkan jumlah baris: "))

# Loop untuk membuat pola
for i in range(1, baris + 1):
    for j in range(1, i + 1):
        print("*", end=" ")
    print()  # Pindah ke baris berikutnya
# Out:
# Masukkan jumlah baris: 10
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * * * *
# * * * * * * *
# * * * * * * * *
# * * * * * * * * *
# * * * * * * * * * *

# %%
#Menamai Pasangan Hewan
hewan1 = ["Kucing", "Kelinci", "Hamster"]
hewan2 = ["Besar", "Kecil"]
print("Pasangan hewan:")
for h1 in hewan1:
    for h2 in hewan2:
        print(h1, h2)
# Out:
# Pasangan hewan:
# Kucing Besar
# Kucing Kecil
# Kelinci Besar
# Kelinci Kecil
# Hamster Besar
# Hamster Kecil

# %%
#Daftar Hari dan Waktu
hari = ["Senin", "Selasa", "Rabu"]
waktu = ["Pagi", "Siang", "Malam"]
print("Jadwal hari dan waktu:")
for h in hari:
    for w in waktu:
        print(h, w)

# %%
#Permainan Tebak Angka
angka_rahasia = [1, 3, 5]
angka_tebakan = [2, 3, 4, 5]
print("Hasil tebakan angka:")
for rahasia in angka_rahasia:
    for tebakan in angka_tebakan:
        if rahasia == tebakan:
            print(f"Benar! Angka {tebakan} cocok.")
        else:
            print(f"Angka {tebakan} salah.")

# %% [markdown]
# **ELSE, BREAK, CONTINUE**

# %%
# ============ WHILE DENGAN ELSE ============ #

b = 1
while b < 5:
    print("b masih lebih kecil dari 5")
    b = b + 1
else:
    print("b sekarang sama dengan 5")


# break : menghentikan iterasi total


print("\n-------BREAK-----------")


skill = ["Python", "R", "Julia", "Scala"]     # data dalam bentuk list

print("start loop")
for val in skill:
    # jika val = "Julia" hentikan iterasi
    if val == "Julia":
        break

    print("  Bahasa", val)

print("end loop")


# continue ; menghentikan iterasi saat ini
# dan langsung melanjutkan iterasi berikutnya

print("\n------CONTINUE---------")

print("start loop")
a = 0
while a < 5:
    a = a + 1

    # jika nilai a 2 atau 3 : continue
    if a == 2 or a == 3:
        continue

    print("  nilai a =", a)

print("end loop")
# Out:
# b masih lebih kecil dari 5
# b masih lebih kecil dari 5
# b masih lebih kecil dari 5
# b masih lebih kecil dari 5
# b sekarang sama dengan 5
#
# -------BREAK-----------
# start loop
#   Bahasa Python
#   Bahasa R
# end loop
#
# ------CONTINUE---------
# start loop
#   nilai a = 1
#   nilai a = 4
#   nilai a = 5
# end loop

# %%
#latihan p7 zikri ramadhan
# Program untuk menghitung total belanja

# Meminta input jumlah barang yang dibeli
jumlah_barang = int(input("Masukkan jumlah barang yang dibeli: "))

# Inisialisasi total belanja
total_belanja = 0

# Loop untuk menghitung total belanja berdasarkan harga dan jumlah barang
for i in range(jumlah_barang):
    print(f"\nBarang ke-{i+1}:")

    # Memasukkan harga satuan dan jumlah unit barang
    harga_satuan = float(input("Masukkan harga satuan barang: "))
    jumlah_unit = int(input("Masukkan jumlah unit barang: "))

    # Menghitung total harga untuk barang ini dan menambahkannya ke total belanja
    total_harga_barang = harga_satuan * jumlah_unit
    total_belanja += total_harga_barang

    # Menampilkan total harga untuk barang ini
    print(f"Total harga barang {i+1}: {total_harga_barang:.2f}")

# Menampilkan total belanja keseluruhan
print(f"\nTotal belanja keseluruhan: {total_belanja:.2f}")
# Out:
# Masukkan jumlah barang yang dibeli: 2
#
# Barang ke-1:
# Masukkan harga satuan barang: 2000
# Masukkan jumlah unit barang: 2
# Total harga barang 1: 4000.00
#
# Barang ke-2:
# Masukkan harga satuan barang: 3
# Masukkan jumlah unit barang: 4000
# Total harga barang 2: 12000.00
#
# Total belanja keseluruhan: 16000.00
